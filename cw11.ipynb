# %%
import matplotlib.pyplot as plt
import numpy as np
import odes

# %% [markdown]
# Alley, Jessica, Paul

# %% [markdown]
# ### Graphing ODE's
# - Each method will observe values of N = 10, 100, & 1000

# %% [markdown]
# ### Euler's Method

# %%
odes.euler(10)

# %%
odes.euler(100)

# %%
odes.euler(1000)

# %% [markdown]
# As the value of N increases, the predicted graph becomes more accurate. The idea of Euler's Method is that the curve is initially unknown but the starting point is known. From a differential equation the slope to the curve at the starting point can be computed and the tangent line. Since just the tangent is used, the graph will rapidly stray away from the exact graph at lower N values.

# %% [markdown]
# ### Heun's Method

# %%
odes.heun(10)

# %%
odes.heun(100)

# %%
odes.heun(1000)

# %% [markdown]
# Heun's Method is accurate because it improves quadratically (higher values of N) rather than linearly (seen in Euler's Method).

# %% [markdown]
# ### 2nd-order Runge Kutta Method

# %%
odes.rk2(10)

# %%
odes.rk2(100)

# %%
odes.rk2(1000)

# %% [markdown]
# For the Runge Kutta methods, midpoints of slopes are used rather than tangent lines. Both estimated graphs shoot up rather than down in Euler's method. The width of the graphs become accurate at higher N values.

# %% [markdown]
# ### 4th-order Runge Kutta Method

# %%
odes.rk4(10)

# %%
odes.rk4(100)

# %%
odes.rk4(1000)

# %% [markdown]
# In my opinion, the 4th-order Runge Kutta method is the most accurate (along with Heun's). Using four approximations will yeild a more accurate graph rather than two. Also, the graph becomes more accurate in both width and height.
